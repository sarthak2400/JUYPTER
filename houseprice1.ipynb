# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns

# %%
df=pd.read_csv("Housing (1).csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
#Check for infinite values and replace them with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Drop rows with NaN values¶
df.dropna(subset=['price'], inplace=True)

# %%
# Scatter Plot of Price vs Area
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x='area', y='price', data=df)
plt.title('Price vs Area')
plt.xlabel('Area (sq ft)')
plt.ylabel('Price ( in cr )')
plt.show()

# %%
#Count Plot of Bedrooms with numbers
plt.figure(figsize=(10, 6))
sns.countplot(x='bedrooms', data=df)
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
plt.show()

# %%
# Count Plot of Bathrooms
plt.figure(figsize=(10, 6))
sns.countplot(x='bathrooms', data=df, palette='viridis')
plt.title('Number of Bathrooms')
plt.xlabel('Bathrooms')
plt.ylabel('Count')
plt.show()

# %%
                                               #Prediction

# %%
# now pure dataset me se sirf kuch hi columns ko select karlo
df = df[['price', 'area', 'bedrooms', 'bathrooms']]

# %%
X = df[['area', 'bedrooms', 'bathrooms']]
Y = df['price']

# %%
X.shape
# Out:
# (545, 3)

# %%
pip install autopep8
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: autopep8 in c:\programdata\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: pycodestyle>=2.8.0 in c:\programdata\anaconda3\lib\site-packages (from autopep8) (2.10.0)
# Requirement already satisfied: toml in c:\programdata\anaconda3\lib\site-packages (from autopep8) (0.10.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
                    #Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
                   #Initializing the linear regression model
model = LinearRegression()

# %%
                    #Training the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
              #Making predictions
y_pred = model.predict(X_test)
y_pred
# Out:
# array([6477084.80205422, 6290684.59564129, 3606519.62702922,
#        4342529.95591905, 3976123.20760112, 4948510.34736794,
#        5582675.87330283, 6156478.89727603, 3324668.28216927,
#        3532207.3394467 , 8840970.17544488, 3569174.32383527,
#        3493779.08908524, 3673133.01187667, 3979646.34941187,
#        6699226.26406605, 2887798.69763635, 4694844.13699399,
#        4641997.00983275, 4297055.42193609, 4349576.23954055,
#        4985503.33638081, 3468764.78222892, 3919752.93862913,
#        5487551.0444126 , 7509691.66216057, 3271821.15500803,
#        5057584.96187901, 7231506.24073354, 3240112.87871128,
#        5409899.14295394, 3680179.29549817, 6114527.50510382,
#        4911517.35835508, 4661047.98023508, 5621287.65159891,
#        4217810.73581852, 4099106.86142056, 3807012.40068515,
#        5380330.75636794, 5392426.21552236, 3462070.81278849,
#        6262499.46115529, 4060678.6110591 , 4561291.0577423 ,
#        4256539.29111248, 6114527.50510382, 4613485.56578997,
#        5019299.49313972, 3240112.87871128, 6634190.92218935,
#        3240112.87871128, 4920651.52243873, 4166372.86538158,
#        4261171.38471503])

# %%
                 #Visualizing the results
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred )
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices (Linear Regression)')
plt.show()
